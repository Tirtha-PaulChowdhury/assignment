# %% [markdown]
# #### In this assignment students have to transform iris data into 3 dimensionsand plot a 3d chart with transformed dimensions and colour each data point with specific class.
# ##### Hint:
# ##### import numpy as np
# ##### import matplotlib.pyplot as plt
# ##### from mpl_toolkits.mplot3d import Axes3D
# ##### from sklearn import decomposition
# ##### from sklearn import datasets

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
from sklearn import decomposition
from sklearn import datasets

iris = datasets.load_iris()

X_reduced = decomposition.PCA(n_components = 3).fit_transform(iris.data)
Y = iris.target

fig = plt.figure(1 , figsize = (8,6))
ax = Axes3D(fig)

ax.scatter(X_reduced[: , 0] , X_reduced[:, 1] , X_reduced[:, 2] , c = Y , cmap = 'rainbow')

ax.set_title('SCATTERPLOT')
ax.set_xlabel('1st eigenvector')
ax.set_ylabel('2nd eigenvector')
ax.set_zlabel('3rd eigenvector')
# Out:
# Text(0.5, 0, '3rd eigenvector')
